# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">IMPORTANT PLEASE READ - Emails with SendGrid</h2>
#             <span style="color:#ff7800;">We are going to use the email provider SendGrid. But this is OPTIONAL.<br/>
#             The next cell contains instructions for SendGrid. But if this gives you problems, or if you'd rather use any alternative,<br/>
#             please see <a href="https://edwarddonner.com/faq">Q29 on the FAQ page here</a> for the full explanation and alternatives.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up SendGrid
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# __If SendGrid gives you problems, see the alternative implementations on Q29 of my FAQ page at https://edwarddonner.com/faq that includes "Resend Email" in community_contributions/2_lab2_with_resend_email and just skipping email altogether.__
#
# Setting up a SendGrid account is free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool, RunConfig
from openai.types.responses import ResponseTextDeltaEvent
from openai import AsyncOpenAI
from agents.models.openai_provider import OpenAIProvider
from typing import Dict
import os
import httpx
import asyncio
import requests

# from sendgrid.helpers.mail import Mail, Email, To, Content
# import sendgrid

# %%
load_dotenv(override=True)
# Out:
# True

# %%
requests.packages.urllib3.disable_warnings()

response = requests.post(
    "https://api.resend.com/emails",
    headers={
        "Authorization": "Bearer re_HniBVHYA_Mf349LtBTHCh4WRjw8k6zXkz",  # API key
        "Content-Type": "application/json"
    },
    json={
        "from": "onboarding@resend.dev",
        "to": ["isoqovdiyorbek742@gmail.com"],
        "subject": "Test",
        "text": "Salom! Bu Python dan yuborildi."
    },
    verify=False  # SSL o'chirildi
)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'id': '45c30210-410f-4b86-9bba-39b6fe45f006'}

# %%
# Let's just check emails are working for you

def send_test_email():
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("ed@edwarddonner.com")  # Change to your verified sender
    to_email = To("ed.donner@gmail.com")  # Change to your recipient
    content = Content("text/plain", "This is an important test email")
    mail = Mail(from_email, to_email, "Test email", content).get()
    response = sg.client.mail.send.post(request_body=mail)
    print(response.status_code)

send_test_email()

# %% [markdown]
# ### Did you receive the test email
#
# If you get a 202, then you're good to go!
#
# #### Certificate error
#
# If you get an error SSL: CERTIFICATE_VERIFY_FAILED then students Chris S and Oleksandr K have suggestions:
# First run this: `!uv pip install --upgrade certifi`
# Next, run this:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# #### Other errors or no email
#
# If there are other problems, you'll need to check your API key and your verified sender email address in the SendGrid dashboard
#
# Or use the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# (Or - you could always replace the email sending code below with a Pushover call, or something to simply write to a flat file)

# %% [markdown]
# ## Step 1: Agent workflow

# %%
client = AsyncOpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
    http_client=httpx.AsyncClient(verify=False)
)

provider = OpenAIProvider(openai_client=client, use_responses=False)

run_config = RunConfig(model_provider=provider, tracing_disabled=True)

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="llama-3.3-70b-versatile"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="llama-3.3-70b-versatile"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="llama-3.3-70b-versatile"
)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email", run_config=run_config)
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Subject: Streamline Your SOC 2 Compliance with ComplAI
#
# Dear [Recipient's Name],
#
# I hope this email finds you well. As a [Recipient's Job Title] at [Company Name], I'm sure you understand the importance of maintaining SOC 2 compliance in today's ever-evolving regulatory landscape. Ensuring the security and integrity of your customers' sensitive data is not only a moral obligation but also a critical component of your business's reputation and growth.
#
# At ComplAI, we've developed an innovative SaaS tool that leverages AI to simplify and accelerate the SOC 2 compliance process. Our platform is designed to help organizations like yours navigate the complexities of SOC 2 audits, reducing the time and resources required to achieve and maintain compliance.
#
# With ComplAI, you'll be able to:
#
# * Automate compliance monitoring and reporting
# * Identify and remediate potential security risks in real-time
# * Streamline audit preparation and reduce the burden on your team
# * Scale your compliance program with ease, as your business grows
#
# Our AI-powered platform has already helped numerous organizations achieve SOC 2 compliance efficiently and effectively. I'd love to schedule a call to discuss how ComplAI can support [Company Name] in achieving and maintaining SOC 2 compliance.
#
# Would you be open to a brief call next [Propose specific days of the week, e.g., Wednesday or Thursday] to explore how our solution can address your compliance needs?
#
# Please let me know if this is something that interests you, and I'll send over a calendar invite.
#
# Best regards,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Email Address]
# [Your Phone Number]
#
# This email aims to introduce the recipient to ComplAI's SOC 2 compliance solution, highlighting its key benefits and value proposition. By personalizing the email and addressing the recipient's potential pain points, the goal is to pique their interest and schedule a follow-up call to discuss further.
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message, run_config=run_config),
        Runner.run(sales_agent2, message, run_config=run_config),
        Runner.run(sales_agent3, message, run_config=run_config),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# Subject: Simplify SOC2 Compliance with AI-Powered Solutions
#
# Dear [Recipient's Name],
#
# I hope this email finds you well. As a [Recipient's Job Title] at [Company Name], I'm sure you understand the importance of maintaining the highest levels of security and compliance in your organization. With the increasing demand for SOC2 compliance, it can be overwhelming to navigate the complexities of audit preparation and ongoing monitoring.
#
# That's where ComplAI comes in. Our innovative SaaS tool, powered by artificial intelligence, is designed to streamline your SOC2 compliance journey. Our platform provides a comprehensive framework to identify, assess, and remediate risks, ensuring that your organization meets the rigorous standards of SOC2.
#
# With ComplAI, you can:
#
# * Automate risk assessments and gap analyses
# * Receive real-time monitoring and alerts for potential security threats
# * Access a library of pre-built controls and templates to simplify audit preparation
# * Collaborate with auditors and stakeholders through a secure, centralized platform
#
# By leveraging AI-powered technology, ComplAI helps reduce the administrative burden associated with SOC2 compliance, freeing up your team to focus on what matters most – growing your business.
#
# I'd love to schedule a call to discuss how ComplAI can support your organization's compliance goals. Would you be available for a 15-minute call next [Proposed Day/Week]?
#
# Please let me know if you're interested, and I'll send over a calendar invite. If you have any questions or would like to learn more about ComplAI, feel free to reply to this email or visit our website at [Company Website].
#
# Thank you for your time, and I look forward to the possibility of working together.
#
# Best regards,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Contact Information]
#
#
# Here's a cold sales email with a dash of humor:
#
# Subject: Don't Let SOC2 Audits Haunt Your Dreams
#
# Dear [Name],
#
# Are SOC2 audits keeping you up at night? Are you tired of sifting through endless spreadsheets, manually tracking controls, and praying that your audit goes smoothly? Well, put down that extra shot of espresso and take a deep breath - we've got your back!
#
# At ComplAI, our AI-powered SaaS tool is like having a superhero sidekick that helps you prepare for audits in a fraction of the time. With our platform, you can:
#
# Automate control monitoring and evidence collection
# Get real-time alerts for potential risks and gaps
# Streamline your audit prep process with customizable workflows
#
# In short, we help you achieve SOC2 compliance without losing your mind (or your social life).
#
# I'd love to schedule a quick call to show you how ComplAI can save you from the SOC2 audit blues. Are you in?
#
# Click this link to book a demo at your convenience: [Calendly link]
#
# Looking forward to chatting with you and helping you conquer the world of SOC2 compliance!
#
# Best,
# [Your Name]
#
# P.S. If you're feeling adventurous, reply to this email with your favorite audit-related horror story. I promise not to judge (much).
#
#
# Subject: Simplify SOC2 Compliance with ComplAI
#
# Dear [Recipient's Name],
#
# Are SOC2 audits taking up too much of your time and resources? ComplAI's AI-powered SaaS tool can help you streamline compliance and prepare for audits with ease.
#
# Our solution automates evidence collection, monitors controls in real-time, and provides actionable insights to ensure your organization meets the highest security standards.
#
# Interested in learning more? I'd be happy to schedule a demo to show you how ComplAI can simplify your SOC2 compliance journey.
#
# Best,
# [Your Name]
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="llama-3.3-70b-versatile"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message, run_config=run_config),
        Runner.run(sales_agent2, message, run_config=run_config),
        Runner.run(sales_agent3, message, run_config=run_config),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails, run_config=run_config)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Streamline Your SOC 2 Compliance with ComplAI
#
# Dear [Recipient's Name],
#
# I came across your company, [Company Name], and was impressed by the innovative work you're doing in [Industry/Field]. As a leader in the industry, I'm sure you understand the importance of maintaining the highest standards of security and compliance.
#
# With the ever-evolving regulatory landscape, ensuring SOC 2 compliance can be a time-consuming and resource-intensive process. That's where ComplAI comes in. Our cutting-edge SaaS tool, powered by artificial intelligence, is designed to simplify and streamline your SOC 2 compliance journey.
#
# ComplAI's AI-driven platform helps you:
#
# * Identify and mitigate potential security risks
# * Automate evidence collection and audit preparation
# * Ensure continuous monitoring and compliance with SOC 2 requirements
# * Reduce the burden on your internal teams and minimize audit fatigue
#
# By leveraging ComplAI, you can:
#
# * Enhance your security posture and protect sensitive data
# * Increase efficiency and reduce compliance costs
# * Improve audit readiness and reduce the risk of non-compliance
# * Focus on growth and innovation, while maintaining the trust of your customers and stakeholders
#
# I'd love to schedule a call to discuss how ComplAI can support your company's SOC 2 compliance goals. If you're interested, please let me know a convenient time, and I'll make sure to schedule it accordingly.
#
# Best regards,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Email Address]
# [Your Phone Number]
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="llama-3.1-8b-instant",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="llama-3.1-8b-instant",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="llama-3.1-8b-instant",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='llama-3.3-70b-versatile', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects """
    
    requests.packages.urllib3.disable_warnings()

    response = requests.post(
        "https://api.resend.com/emails",
        headers={
            "Authorization": "Bearer re_HniBVHYA_Mf349LtBTHCh4WRjw8k6zXkz",  # API key
            "Content-Type": "application/json"
        },
        json={
            "from": "onboarding@resend.dev",
            "to": ["isoqovdiyorbek742@gmail.com"],
            "subject": "Sales Email",
            "text": f"{body}"
        },
        verify=False  # SSL o'chirildi
    )
    return {"status": "success"}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000211D23BB110>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000211D2549F30>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282658D4C90>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282658D4DE0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282658D4FA0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282658D49F0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model='llama-3.3-70b-versatile')

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message, run_config=run_config)
# Out:
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: request failed: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And one more suggestion to send emails from student Oleksandr on Windows 11:
#
# If you are getting certificate SSL errors, then:
# Run this in a terminal: `uv pip install --upgrade certifi`
#
# Then run this code:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# Thank you Oleksandr!

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="llama-3.1-8b-instant")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="llama-3.1-8b-instant")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("ed@edwarddonner.com")  # Change to your verified sender
    to_email = To("ed.donner@gmail.com")  # Change to your recipient
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
@function_tool
def send_html_email(subject: str, html_body: str):
    """ Send out an email with the given body to all sales prospects """
    
    requests.packages.urllib3.disable_warnings()

    response = requests.post(
        "https://api.resend.com/emails",
        headers={
            "Authorization": "Bearer re_HniBVHYA_Mf349LtBTHCh4WRjw8k6zXkz",  # API key
            "Content-Type": "application/json"
        },
        json={
            "from": "onboarding@resend.dev",
            "to": ["isoqovdiyorbek742@gmail.com"],
            "subject": f"{subject}",
            "html": f"{html_body}"
        },
        verify=False  # SSL o'chirildi
    )
    print(response.status_code)
    print(response.text)
    return {"status": "success"}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools
# Out:
# [FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282612720B0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None),
#  FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x00000282612EC1D0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None),
#  FunctionTool(name='send_html_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x000002825C356F30>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)]

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="llama-3.1-8b-instant",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A20C20>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None), FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A20D70>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None), FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A20F30>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)]
# [Agent(name='Email Manager', handoff_description='Convert an email to HTML and send it', tools=[FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A21240>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None), FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A21400>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None), FunctionTool(name='send_html_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000028262A217F0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None)], mcp_servers=[], mcp_config={}, instructions='You are an email formatter and sender. You receive the body of an email to be sent. You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. Finally, you use the send_html_email tool to send the email with the subject and HTML body.', prompt=None, handoffs=[], model='llama-3.1-8b-instant', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)]

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a legitimate B2B SaaS sales assistant helping businesses connect with potential customers.
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="llama-3.1-8b-instant")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

# with trace("Automated SDR"):
result = await Runner.run(sales_manager, message, run_config=run_config)
# Out:
# Error getting response; filtered.input=[{'content': 'Send out a cold sales email addressed to Dear CEO from Alice', 'role': 'user'}]
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[42], line 31
#      28 message = "Send out a cold sales email addressed to Dear CEO from Alice"
#      30 # with trace("Automated SDR"):
# ---> 31 result = await Runner.run(sales_manager, message, run_config=run_config)
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\run.py:222, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     172 """
#     173 Run a workflow starting at the given agent.
#     174
#    (...)    218     type of the output.
#     219 """
#     221 runner = DEFAULT_AGENT_RUNNER
# --> 222 return await runner.run(
#     223     starting_agent,
#     224     input,
#     225     context=context,
#     226     max_turns=max_turns,
#     227     hooks=hooks,
#     228     run_config=run_config,
#     229     error_handlers=error_handlers,
#     230     previous_response_id=previous_response_id,
#     231     auto_previous_response_id=auto_previous_response_id,
#     232     conversation_id=conversation_id,
#     233     session=session,
#     234 )
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\run.py:1054, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1052         raise
#    1053 else:
# -> 1054     turn_result = await model_task
#    1056 input_guardrail_results.extend(sequential_results)
#    1057 input_guardrail_results.extend(parallel_results)
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1407, in run_single_turn(agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy)
#    1404 if isinstance(input, list):
#    1405     input = normalize_input_items_for_api(input)
# -> 1407 new_response = await get_new_response(
#    1408     agent,
#    1409     system_prompt,
#    1410     input,
#    1411     output_schema,
#    1412     all_tools,
#    1413     handoffs,
#    1414     hooks,
#    1415     context_wrapper,
#    1416     run_config,
#    1417     tool_use_tracker,
#    1418     server_conversation_tracker,
#    1419     prompt_config,
#    1420     session=session,
#    1421     session_items_to_rewind=session_items_to_rewind,
#    1422 )
#    1424 return await get_single_step_result_from_response(
#    1425     agent=agent,
#    1426     original_input=original_input,
#    (...)   1435     tool_use_tracker=tool_use_tracker,
#    1436 )
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1502, in get_new_response(agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind)
#    1499     logger.debug("No conversation_id available for request")
#    1501 try:
# -> 1502     new_response = await model.get_response(
#    1503         system_instructions=filtered.instructions,
#    1504         input=filtered.input,
#    1505         model_settings=model_settings,
#    1506         tools=all_tools,
#    1507         output_schema=output_schema,
#    1508         handoffs=handoffs,
#    1509         tracing=get_model_tracing_impl(
#    1510             run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1511         ),
#    1512         previous_response_id=previous_response_id,
#    1513         conversation_id=conversation_id,
#    1514         prompt=prompt_config,
#    1515     )
#    1516 except Exception as exc:
#    1517     from openai import BadRequestError
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\models\openai_chatcompletions.py:73, in OpenAIChatCompletionsModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#      55 async def get_response(
#      56     self,
#      57     system_instructions: str | None,
#    (...)     66     prompt: ResponsePromptParam | None = None,
#      67 ) -> ModelResponse:
#      68     with generation_span(
#      69         model=str(self.model),
#      70         model_config=model_settings.to_json_dict() | {"base_url": str(self._client.base_url)},
#      71         disabled=tracing.is_disabled(),
#      72     ) as span_generation:
# ---> 73         response = await self._fetch_response(
#      74             system_instructions,
#      75             input,
#      76             model_settings,
#      77             tools,
#      78             output_schema,
#      79             handoffs,
#      80             span_generation,
#      81             tracing,
#      82             stream=False,
#      83             prompt=prompt,
#      84         )
#      86         message: ChatCompletionMessage | None = None
#      87         first_choice: Choice | None = None
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\agents\models\openai_chatcompletions.py:337, in OpenAIChatCompletionsModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     331 stream_options = ChatCmplHelpers.get_stream_options_param(
#     332     self._get_client(), model_settings, stream=stream
#     333 )
#     335 stream_param: Literal[True] | Omit = True if stream else omit
# --> 337 ret = await self._get_client().chat.completions.create(
#     338     model=self.model,
#     339     messages=converted_messages,
#     340     tools=tools_param,
#     341     temperature=self._non_null_or_omit(model_settings.temperature),
#     342     top_p=self._non_null_or_omit(model_settings.top_p),
#     343     frequency_penalty=self._non_null_or_omit(model_settings.frequency_penalty),
#     344     presence_penalty=self._non_null_or_omit(model_settings.presence_penalty),
#     345     max_tokens=self._non_null_or_omit(model_settings.max_tokens),
#     346     tool_choice=tool_choice,
#     347     response_format=response_format,
#     348     parallel_tool_calls=parallel_tool_calls,
#     349     stream=cast(Any, stream_param),
#     350     stream_options=self._non_null_or_omit(stream_options),
#     351     store=self._non_null_or_omit(store),
#     352     reasoning_effort=self._non_null_or_omit(reasoning_effort),
#     353     verbosity=self._non_null_or_omit(model_settings.verbosity),
#     354     top_logprobs=self._non_null_or_omit(model_settings.top_logprobs),
#     355     prompt_cache_retention=self._non_null_or_omit(model_settings.prompt_cache_retention),
#     356     extra_headers=self._merge_headers(model_settings),
#     357     extra_query=model_settings.extra_query,
#     358     extra_body=model_settings.extra_body,
#     359     metadata=self._non_null_or_omit(model_settings.metadata),
#     360     **(model_settings.extra_args or {}),
#     361 )
#     363 if isinstance(ret, ChatCompletion):
#     364     return ret
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:2700, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2653 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2654 async def create(
#    2655     self,
#    (...)   2697     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2698 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2699     validate_response_format(response_format)
# -> 2700     return await self._post(
#    2701         "/chat/completions",
#    2702         body=await async_maybe_transform(
#    2703             {
#    2704                 "messages": messages,
#    2705                 "model": model,
#    2706                 "audio": audio,
#    2707                 "frequency_penalty": frequency_penalty,
#    2708                 "function_call": function_call,
#    2709                 "functions": functions,
#    2710                 "logit_bias": logit_bias,
#    2711                 "logprobs": logprobs,
#    2712                 "max_completion_tokens": max_completion_tokens,
#    2713                 "max_tokens": max_tokens,
#    2714                 "metadata": metadata,
#    2715                 "modalities": modalities,
#    2716                 "n": n,
#    2717                 "parallel_tool_calls": parallel_tool_calls,
#    2718                 "prediction": prediction,
#    2719                 "presence_penalty": presence_penalty,
#    2720                 "prompt_cache_key": prompt_cache_key,
#    2721                 "prompt_cache_retention": prompt_cache_retention,
#    2722                 "reasoning_effort": reasoning_effort,
#    2723                 "response_format": response_format,
#    2724                 "safety_identifier": safety_identifier,
#    2725                 "seed": seed,
#    2726                 "service_tier": service_tier,
#    2727                 "stop": stop,
#    2728                 "store": store,
#    2729                 "stream": stream,
#    2730                 "stream_options": stream_options,
#    2731                 "temperature": temperature,
#    2732                 "tool_choice": tool_choice,
#    2733                 "tools": tools,
#    2734                 "top_logprobs": top_logprobs,
#    2735                 "top_p": top_p,
#    2736                 "user": user,
#    2737                 "verbosity": verbosity,
#    2738                 "web_search_options": web_search_options,
#    2739             },
#    2740             completion_create_params.CompletionCreateParamsStreaming
#    2741             if stream
#    2742             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2743         ),
#    2744         options=make_request_options(
#    2745             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2746         ),
#    2747         cast_to=ChatCompletion,
#    2748         stream=stream or False,
#    2749         stream_cls=AsyncStream[ChatCompletionChunk],
#    2750     )
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\openai\_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1875     warnings.warn(
#    1876         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1877         "Please pass raw bytes via the `content` parameter instead.",
#    1878         DeprecationWarning,
#    1879         stacklevel=2,
#    1880     )
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\student6\agents\.venv\Lib\site-packages\openai\_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1666             await err.response.aread()
#    1668         log.debug("Re-raising status error")
# -> 1669         raise self._make_status_error_from_response(err.response) from None
#    1671     break
#    1673 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "invalid JSON schema for tool transfer_to_email_manager, tools[3].function.parameters: 'required' present but 'properties' is missing", 'type': 'invalid_request_error', 'param': 'tool transfer_to_email_manager, tools[3].function.parameters'}}

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.
